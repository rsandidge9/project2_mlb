# %%
import pandas as pd

# %%
master_data = pd.read_csv("../project2_mlb/data/Draft_SD_CSV.csv")

# %%
data_grouped_by_year_franch = master_data.groupby(["Year", "Current_Franchise"]).sum()

# %%
data_grouped_by_year_franch
# Out:
#                            Rnd  OvPck  Debut_Year      fg_id  TC_Hitting_WAR  \
# Year Current_Franchise
# 1965 Atlanta Braves        283   6501      3935.0  2017926.0            12.7
#      Baltimore Orioles     679  10580      5901.0  3027648.0             0.1
#      Boston Red Sox        147   2950      9842.0  5035479.0            17.5
#      Chicago Cubs          303   5879     13777.0  7052379.0            -0.4
#      Chicago White Sox     389   7435      7876.0  4029518.0            -1.5
# ...                        ...    ...         ...        ...             ...
# 2019 St. Louis Cardinals   566  17118         0.0        0.0             0.0
#      Tampa Bay Rays        573  17432         0.0        0.0             0.0
#      Texas Rangers         515  15305         0.0        0.0             0.0
#      Toronto Blue Jays     511  15220         0.0        0.0             0.0
#      Washington Nationals  474  14292         0.0        0.0             0.0
#
#                            TC_Pitching_WAR  TC_Total_WAR  Career_Hitting_WAR  \
# Year Current_Franchise
# 1965 Atlanta Braves                    0.2          12.9                17.6
#      Baltimore Orioles                 0.4           0.5                -0.2
#      Boston Red Sox                    0.7          18.2                43.2
#      Chicago Cubs                     27.0          26.6                -0.1
#      Chicago White Sox                 0.7          -0.8                -1.5
# ...                                    ...           ...                 ...
# 2019 St. Louis Cardinals               0.0           0.0                 0.0
#      Tampa Bay Rays                    0.0           0.0                 0.0
#      Texas Rangers                     0.0           0.0                 0.0
#      Toronto Blue Jays                 0.0           0.0                 0.0
#      Washington Nationals              0.0           0.0                 0.0
#
#                            Career_Pitching_WAR  Career_Total_WAR
# Year Current_Franchise
# 1965 Atlanta Braves                        0.2              17.8
#      Baltimore Orioles                     0.4               0.2
#      Boston Red Sox                        0.7              43.9
#      Chicago Cubs                         44.4              44.3
#      Chicago White Sox                     0.7              -0.8
# ...                                        ...               ...
# 2019 St. Louis Cardinals                   0.0               0.0
#      Tampa Bay Rays                        0.0               0.0
#      Texas Rangers                         0.0               0.0
#      Toronto Blue Jays                     0.0               0.0
#      Washington Nationals                  0.0               0.0
#
# [1502 rows x 10 columns]

# %%
data_grouped_by_year_franch.to_csv("data/Data_Grouped_by_Year_and_Franchise.csv")
